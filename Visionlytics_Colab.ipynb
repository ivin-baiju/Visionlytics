# %% [markdown]
# # Visionlytics on Google Colab 🚀
#
# Run the cells below to launch the Visionlytics dashboard inside Google Colab using a **Cloudflare Tunnel** (since localtunnel can be unstable).

# %%
# 1. Clone the repository and install dependencies
# !git clone https://github.com/ivin-baiju/Visionlytics.git
# %cd Visionlytics
# !pip install -e backend/
# !pip install -e frontend/

# %%
# 2. Install localtunnel (Cloudflare quick tunnels are disabled)
# !npm install -q -g localtunnel
# !wget -q -O - ipv4.icanhazip.com

# %%
# 3. Run Microservices in the background and expose it via Localtunnel
import subprocess
import time

# Start Both FastAPI and Streamlit
# !chmod +x start.sh
subprocess.Popen(['./start.sh'])

# Give servers a few seconds to boot up
time.sleep(8)

# Start localtunnel to expose Streamlit
print("\n\n====== YOUR APP URL IS GENERATING BELOW ======\n")
print("NOTE: Copy the IP address from the previous cell to unlock the tunnel.\n")
# !npx localtunnel --port 8501
