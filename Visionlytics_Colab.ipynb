# %% [markdown]
# # Visionlytics on Google Colab 🚀
#
# Run the cells below to launch the Visionlytics dashboard inside Google Colab using `localtunnel`.

# %%
# 1. Clone the repository and install dependencies
# !git clone https://github.com/ivin-baiju/Visionlytics.git
# %cd Visionlytics
# !pip install -r requirements.txt

# %%
# 2. Install localtunnel to expose the Streamlit port
# !npm install localtunnel

# %%
# 3. Fetch your public IP (needed for localtunnel password)
import urllib
print("Password/Endpoint IP for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))

# %%
# 4. Run Streamlit in the background and start localtunnel
# Click the localtunnel url that is generated below and enter the password from above.
# !streamlit run app/main.py &> /dev/null & npx localtunnel --port 8501
